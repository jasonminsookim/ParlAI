# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import pandas as pd
from tqdm.notebook import tqdm
from collections import defaultdict, Counter
from empath import Empath
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to /Users/jasonkim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jasonkim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
scored_df = pd.read_csv('../data/scored_chatbot_interactions/processed/JasonMcFadden_scored_chats_processed.csv')
scored_df.head()
# Out:
#    Unnamed: 0  iteration                                              input  \
# 0           0          0  I suffer from debilitating social anxiety, whi...
# 1           2          0   I'd like to feel more confident and less anxious
# 2           3          0  I'm anxious about my presentation, I think I w...
# 3           4          0  I'm really overloaded with work and have a ton...
# 4           5          0  I'm feeling really stressed out all the time a...
#
#                                        cb_response_1  \
# 0  it is possible that you ' ll eventually experi...
# 1  i ' d like to feel more confident and less anx...
# 2  the problem is that you are not prepared enough .
# 3  there are many different types of psychologist...
# 4  a therapist may be helpful , but they don ' t ...
#
#                              input_2  \
# 0  Oh really, should I be concerned?
# 1       Do you have any suggestions?
# 2   I'm well prepared, just anxious.
# 3    Which psychologist can help me?
# 4    So I should see a psychologist?
#
#                                        cb_response_2  \
# 0  not at all . there are many different therapie...
# 1                i ' d want to feel more confident .
# 2           you are not prepared to be a therapist .
# 3  i don ' t know of a specific type of psycholog...
# 4  i ' d recommend getting a copy of the book you...
#
#                                              input_3  \
# 0  Oh that's great, what kind of therapies are th...
# 1                Same here. Any tips on how to help?
# 2      I know. Any tips on how to manage my anxiety?
# 3                 Do you have any other suggestions?
# 4  Thank you. Any other tips for how to manage my...
#
#                                        cb_response_3  cbr1_score  cbrall_score
# 0  there are many different therapies for depress...         6.5           7.0
# 1  i would like to help with how to get rid of an...         2.0           2.0
# 2  you need to be aware that there is a time and ...         1.0           2.0
# 3  it ' s not clear what types of therapy are app...         4.0           6.0
# 4  the most common way you can manage stress is t...         8.0           8.5

# %%
def add_prefix_to_dict_keys(dict, prefix):
    return {f'{prefix}_{k}': v for k, v in dict.items()}

def calc_similarity_between_strings(all_data_df_row):
    x = all_data_df_row['input']
    y = all_data_df_row['cb_response_1']

    # tokenization first
    x_list = word_tokenize(x)
    y_list = word_tokenize(y)

    # Check for stop words
    sw = stopwords.words('english')  
    l1 = list()
    l2 = list()

    # Remove stop words from string
    x_set = {w for w in x_list if not w in sw}  
    y_set = {w for w in y_list if not w in sw}  


    # form a set containing keywords of both strings  
    rvector = x_set.union(y_set)  
    for w in rvector: 
        if w in x_set: l1.append(1) # create a vector 
        else:l1.append(0) 
        if w in y_set: l2.append(1) 
        else: l2.append(0) 
    c = 0

    # cosine formula  
    for i in range(len(rvector)): 
          c+= l1[i]*l2[i] 
    cosine = c / float((sum(l1)*sum(l2))**0.5) 
    return cosine

# %%
class SeanceScorer():

    def __init__(self):
        # add in inquiererbasic.txt
        with open('../data/inputs/seance/inquirerbasic.txt', 'r') as content_file:
            content = content_file.read()

        split_by_metric = content.split('\n')

        self.seance_dict = {}
        for line in split_by_metric:
            word_list = line.split('\t')
            self.seance_dict[f'{word_list[0]}'] = word_list[1:]

        # add in negative_words.txt
        with open('../data/inputs/seance/negative_words.txt', 'r') as content_file:
            content = content_file.read()

        self.seance_dict['negative_words'] = content.split('\n')

        # add in positive_words.txt
        with open('../data/inputs/seance/positive_words.txt', 'r') as content_file:
            content = content_file.read()

        self.seance_dict['positive_words'] = content.split('\n')
    

    def calc_seance_scores(self, text_to_score, type_scored):
        scores_dict = {}
        for dict_key in self.seance_dict.keys():
            cur_list = self.seance_dict[dict_key] # The list of words associated with the seance feature
            counted = Counter(text_to_score.split())
            common_words = set(cur_list).intersection(counted)
            count_common = sum(counted[wrd] for wrd in set(cur_list))
            scores_dict[f'{type_scored}_s_{dict_key}'] = count_common
        return(scores_dict)

# %%
# Initalize scorers
seance_scorer = SeanceScorer() # from custom made seance scorer
lexicon = Empath() # from empath library
analyzer = SentimentIntensityAnalyzer()


all_scores_list = []

for i in tqdm(range(len(scored_df))):
    seance_input_scores = pd.DataFrame(seance_scorer.calc_seance_scores(scored_df['input'][i], type_scored='prompt'), index=[i])
    seance_output_scores = pd.DataFrame(seance_scorer.calc_seance_scores(scored_df['cb_response_1'][i], type_scored='response'), index=[i])
    empath_input_scores = pd.DataFrame(add_prefix_to_dict_keys(lexicon.analyze(scored_df['input'][i]), prefix='prompt_e'), index=[i])
    empath_output_scores = pd.DataFrame(add_prefix_to_dict_keys(lexicon.analyze(scored_df['cb_response_1'][i]), prefix='response_e'), index=[i])
    vader_input_scores = pd.DataFrame(add_prefix_to_dict_keys(analyzer.polarity_scores(scored_df['input'][i]), prefix='prompt_v'), index=[i])
    vader_output_scores = pd.DataFrame(add_prefix_to_dict_keys(analyzer.polarity_scores(scored_df['cb_response_1'][i]), prefix='response_v'), index=[i])
    all_scores_list.append(pd.concat([seance_input_scores, seance_output_scores, empath_input_scores, empath_output_scores, vader_input_scores, vader_output_scores], axis=1))
    all_scores = pd.concat(all_scores_list)
    
    
all_data = pd.concat([scored_df, all_scores], axis = 1)
all_data['prompt_response_similarity'] = all_data.apply(calc_similarity_between_strings, axis =1)
# Out:
# HBox(children=(IntProgress(value=0, max=381), HTML(value='')))

# %% [markdown]
# ## How to cull columns?
#
# - Look into the variability across columns
#     - Less than 5 percent of the data are required to be different from the modal value.
# - Do a PCA among the columns that appear to measure the same thing
#     - E.g. positive sentiment
# - Also use number of unique values
# - Drop linear features
#     - Drop columns with high correlation, e.g. > .96

# %%
all_data.head()
# Out:
#    Unnamed: 0  iteration                                              input  \
# 0           0          0  I suffer from debilitating social anxiety, whi...
# 1           2          0   I'd like to feel more confident and less anxious
# 2           3          0  I'm anxious about my presentation, I think I w...
# 3           4          0  I'm really overloaded with work and have a ton...
# 4           5          0  I'm feeling really stressed out all the time a...
#
#                                        cb_response_1  \
# 0  it is possible that you ' ll eventually experi...
# 1  i ' d like to feel more confident and less anx...
# 2  the problem is that you are not prepared enough .
# 3  there are many different types of psychologist...
# 4  a therapist may be helpful , but they don ' t ...
#
#                              input_2  \
# 0  Oh really, should I be concerned?
# 1       Do you have any suggestions?
# 2   I'm well prepared, just anxious.
# 3    Which psychologist can help me?
# 4    So I should see a psychologist?
#
#                                        cb_response_2  \
# 0  not at all . there are many different therapie...
# 1                i ' d want to feel more confident .
# 2           you are not prepared to be a therapist .
# 3  i don ' t know of a specific type of psycholog...
# 4  i ' d recommend getting a copy of the book you...
#
#                                              input_3  \
# 0  Oh that's great, what kind of therapies are th...
# 1                Same here. Any tips on how to help?
# 2      I know. Any tips on how to manage my anxiety?
# 3                 Do you have any other suggestions?
# 4  Thank you. Any other tips for how to manage my...
#
#                                        cb_response_3  cbr1_score  \
# 0  there are many different therapies for depress...         6.5
# 1  i would like to help with how to get rid of an...         2.0
# 2  you need to be aware that there is a time and ...         1.0
# 3  it ' s not clear what types of therapy are app...         4.0
# 4  the most common way you can manage stress is t...         8.0
#
#    cbrall_score  ...  response_e_musical  prompt_v_neg  prompt_v_neu  \
# 0           7.0  ...                 0.0         0.373         0.582
# 1           2.0  ...                 0.0         0.125         0.438
# 2           2.0  ...                 0.0         0.333         0.667
# 3           6.0  ...                 0.0         0.000         1.000
# 4           8.5  ...                 0.0         0.187         0.625
#
#    prompt_v_pos  prompt_v_compound  response_v_neg  response_v_neu  \
# 0         0.045            -0.8625           0.286           0.714
# 1         0.437             0.6470           0.109           0.510
# 2         0.000            -0.5423           0.353           0.647
# 3         0.000             0.0000           0.000           0.903
# 4         0.188            -0.2484           0.000           0.934
#
#    response_v_pos  response_v_compound  prompt_response_similarity
# 0           0.000              -0.5267                    0.195180
# 1           0.382               0.6470                    0.771517
# 2           0.000              -0.5213                    0.000000
# 3           0.097               0.4019                    0.111803
# 4           0.066               0.2263                    0.184900
#
# [5 rows x 795 columns]

# %%
all_data.shape
# Out:
# (381, 795)

# %%
all_data.columns.values
# Out:
# array(['Unnamed: 0', 'iteration', 'input', 'cb_response_1', 'input_2',
#        'cb_response_2', 'input_3', 'cb_response_3', 'cbr1_score',
#        'cbrall_score', 'prompt_s_Positiv_GI', 'prompt_s_Negativ_GI',
#        'prompt_s_Pstv_GI', 'prompt_s_Affil_GI', 'prompt_s_Ngtv_GI',
#        'prompt_s_Hostile_GI', 'prompt_s_Strong_GI', 'prompt_s_Power_GI',
#        'prompt_s_Weak_GI', 'prompt_s_Submit_GI', 'prompt_s_Active_GI',
#        'prompt_s_Passive_GI', 'prompt_s_Pleasur_GI', 'prompt_s_Pain_GI',
#        'prompt_s_Feel_GI', 'prompt_s_Arousal_GI', 'prompt_s_Emot_GI',
#        'prompt_s_Virtue_GI', 'prompt_s_Vice_GI', 'prompt_s_Ovrst_GI',
#        'prompt_s_Undrst_GI', 'prompt_s_Academ_GI', 'prompt_s_Doctrin_GI',
#        'prompt_s_Econ_2_GI', 'prompt_s_Exch_GI', 'prompt_s_Econ_GI',
#        'prompt_s_Exprsv_GI', 'prompt_s_Legal_GI', 'prompt_s_Milit_GI',
#        'prompt_s_Polit_2_GI', 'prompt_s_Polit_GI', 'prompt_s_Relig_GI',
#        'prompt_s_Role_GI', 'prompt_s_Coll_GI', 'prompt_s_Work_GI',
#        'prompt_s_Ritual_GI', 'prompt_s_Socrel_GI', 'prompt_s_Race_GI',
#        'prompt_s_Kin_2_GI', 'prompt_s_Male_GI', 'prompt_s_Female_GI',
#        'prompt_s_Nonadlt_GI', 'prompt_s_Hu_GI', 'prompt_s_Ani_GI',
#        'prompt_s_Place_GI', 'prompt_s_Social_GI', 'prompt_s_Region_GI',
#        'prompt_s_Route_GI', 'prompt_s_Aquatic_GI', 'prompt_s_Land_GI',
#        'prompt_s_Sky_GI', 'prompt_s_Object_GI', 'prompt_s_Tool_GI',
#        'prompt_s_Food_GI', 'prompt_s_Vehicle_GI', 'prompt_s_Bldgpt_GI',
#        'prompt_s_Comnobj_GI', 'prompt_s_Natobj_GI', 'prompt_s_Bodypt_GI',
#        'prompt_s_Comform_GI', 'prompt_s_Com_GI', 'prompt_s_Say_GI',
#        'prompt_s_Need_GI', 'prompt_s_Goal_GI', 'prompt_s_Try_GI',
#        'prompt_s_Means_GI', 'prompt_s_Persist_GI', 'prompt_s_Complet_GI',
#        'prompt_s_Fail_GI', 'prompt_s_Natrpro_GI', 'prompt_s_Begin_GI',
#        'prompt_s_Vary_GI', 'prompt_s_Increas_GI', 'prompt_s_Decreas_GI',
#        'prompt_s_Finish_GI', 'prompt_s_Stay_GI', 'prompt_s_Rise_GI',
#        'prompt_s_Exert_GI', 'prompt_s_Fetch_GI', 'prompt_s_Travel_GI',
#        'prompt_s_Fall_GI', 'prompt_s_Think_GI', 'prompt_s_Know_GI',
#        'prompt_s_Causal_GI', 'prompt_s_Ought_GI', 'prompt_s_Perceiv_GI',
#        'prompt_s_Compare_GI', 'prompt_s_Eval_2_GI', 'prompt_s_Eval_GI',
#        'prompt_s_Solve_GI', 'prompt_s_Abs_2_GI', 'prompt_s_Abs_GI',
#        'prompt_s_Quality_GI', 'prompt_s_Quan_GI', 'prompt_s_Numb_GI',
#        'prompt_s_Ord_GI', 'prompt_s_Card_GI', 'prompt_s_Freq_GI',
#        'prompt_s_Dist_GI', 'prompt_s_Time_2_GI', 'prompt_s_Time_GI',
#        'prompt_s_Space_GI', 'prompt_s_Pos_GI', 'prompt_s_Dim_GI',
#        'prompt_s_Rel_GI', 'prompt_s_Color_GI', 'prompt_s_Self_GI',
#        'prompt_s_Our_GI', 'prompt_s_You_GI', 'prompt_s_Name_GI',
#        'prompt_s_Yes_GI', 'prompt_s_No_GI', 'prompt_s_Negate_GI',
#        'prompt_s_Intrj_GI', 'prompt_s_Iav_GI', 'prompt_s_Dav_GI',
#        'prompt_s_Sv_GI', 'prompt_s_Ipadj_GI', 'prompt_s_Indadj_GI',
#        'prompt_s_Powgain_Lasswell', 'prompt_s_Powloss_Lasswell',
#        'prompt_s_Powends_Lasswell', 'prompt_s_Powaren_Lasswell',
#        'prompt_s_Powcon_Lasswell', 'prompt_s_Powcoop_Lasswell',
#        'prompt_s_Powaupt_Lasswell', 'prompt_s_Powpt_Lasswell',
#        'prompt_s_Powdoct_Lasswell', 'prompt_s_Powauth_Lasswell',
#        'prompt_s_Powoth_Lasswell', 'prompt_s_Powtot_Lasswell',
#        'prompt_s_Rcethic_Lasswell', 'prompt_s_Rcrelig_Lasswell',
#        'prompt_s_Rcgain_Lasswell', 'prompt_s_Rcloss_Lasswell',
#        'prompt_s_Rcends_Lasswell', 'prompt_s_Rctot_Lasswell',
#        'prompt_s_Rspgain_Lasswell', 'prompt_s_Rsploss_Lasswell',
#        'prompt_s_Rspoth_Lasswell', 'prompt_s_Rsptot_Lasswell',
#        'prompt_s_Affgain_Lasswell', 'prompt_s_Affloss_Lasswell',
#        'prompt_s_Affpt_Lasswell', 'prompt_s_Affoth_Lasswell',
#        'prompt_s_Afftot_Lasswell', 'prompt_s_Wltpt_Lasswell',
#        'prompt_s_Wlttran_Lasswell', 'prompt_s_Wltoth_Lasswell',
#        'prompt_s_Wlttot_Lasswell', 'prompt_s_Wlbgain_Lasswell',
#        'prompt_s_Wlbloss_Lasswell', 'prompt_s_Wlbphys_Lasswell',
#        'prompt_s_Wlbpsyc_Lasswell', 'prompt_s_Wlbpt_Lasswell',
#        'prompt_s_Wlbtot_Lasswell', 'prompt_s_Enlgain_Lasswell',
#        'prompt_s_Enlloss_Lasswell', 'prompt_s_Enlends_Lasswell',
#        'prompt_s_Enlpt_Lasswell', 'prompt_s_Enloth_Lasswell',
#        'prompt_s_Enltot_Lasswell', 'prompt_s_Sklasth_Lasswell',
#        'prompt_s_Sklpt_Lasswell', 'prompt_s_Skloth_Lasswell',
#        'prompt_s_Skltot_Lasswell', 'prompt_s_Trngain_Lasswell',
#        'prompt_s_Trnloss_Lasswell', 'prompt_s_Tranlw_Lasswell',
#        'prompt_s_Meanslw_Lasswell', 'prompt_s_Endslw_Lasswell',
#        'prompt_s_Arenalw_Lasswell', 'prompt_s_Ptlw_Lasswell',
#        'prompt_s_Nation_Lasswell', 'prompt_s_Anomie_Lasswell',
#        'prompt_s_Negaff_Lasswell', 'prompt_s_Posaff_Lasswell',
#        'prompt_s_Surelw_Lasswell', 'prompt_s_If_Lasswell',
#        'prompt_s_Notlw_Lasswell', 'prompt_s_Timespc_Lasswell',
#        'prompt_s_formlw_Lasswell', 'prompt_s_Anger_NRC',
#        'prompt_s_Anticipation_NRC', 'prompt_s_Disgust_NRC',
#        'prompt_s_Fear_NRC', 'prompt_s_Joy_NRC', 'prompt_s_Negative_NRC',
#        'prompt_s_Positive_NRC', 'prompt_s_Sadness_NRC',
#        'prompt_s_Surprise_NRC', 'prompt_s_Trust_NRC',
#        'prompt_s_negative_words', 'prompt_s_positive_words',
#        'response_s_Positiv_GI', 'response_s_Negativ_GI',
#        'response_s_Pstv_GI', 'response_s_Affil_GI', 'response_s_Ngtv_GI',
#        'response_s_Hostile_GI', 'response_s_Strong_GI',
#        'response_s_Power_GI', 'response_s_Weak_GI',
#        'response_s_Submit_GI', 'response_s_Active_GI',
#        'response_s_Passive_GI', 'response_s_Pleasur_GI',
#        'response_s_Pain_GI', 'response_s_Feel_GI',
#        'response_s_Arousal_GI', 'response_s_Emot_GI',
#        'response_s_Virtue_GI', 'response_s_Vice_GI',
#        'response_s_Ovrst_GI', 'response_s_Undrst_GI',
#        'response_s_Academ_GI', 'response_s_Doctrin_GI',
#        'response_s_Econ_2_GI', 'response_s_Exch_GI', 'response_s_Econ_GI',
#        'response_s_Exprsv_GI', 'response_s_Legal_GI',
#        'response_s_Milit_GI', 'response_s_Polit_2_GI',
#        'response_s_Polit_GI', 'response_s_Relig_GI', 'response_s_Role_GI',
#        'response_s_Coll_GI', 'response_s_Work_GI', 'response_s_Ritual_GI',
#        'response_s_Socrel_GI', 'response_s_Race_GI',
#        'response_s_Kin_2_GI', 'response_s_Male_GI',
#        'response_s_Female_GI', 'response_s_Nonadlt_GI',
#        'response_s_Hu_GI', 'response_s_Ani_GI', 'response_s_Place_GI',
#        'response_s_Social_GI', 'response_s_Region_GI',
#        'response_s_Route_GI', 'response_s_Aquatic_GI',
#        'response_s_Land_GI', 'response_s_Sky_GI', 'response_s_Object_GI',
#        'response_s_Tool_GI', 'response_s_Food_GI',
#        'response_s_Vehicle_GI', 'response_s_Bldgpt_GI',
#        'response_s_Comnobj_GI', 'response_s_Natobj_GI',
#        'response_s_Bodypt_GI', 'response_s_Comform_GI',
#        'response_s_Com_GI', 'response_s_Say_GI', 'response_s_Need_GI',
#        'response_s_Goal_GI', 'response_s_Try_GI', 'response_s_Means_GI',
#        'response_s_Persist_GI', 'response_s_Complet_GI',
#        'response_s_Fail_GI', 'response_s_Natrpro_GI',
#        'response_s_Begin_GI', 'response_s_Vary_GI',
#        'response_s_Increas_GI', 'response_s_Decreas_GI',
#        'response_s_Finish_GI', 'response_s_Stay_GI', 'response_s_Rise_GI',
#        'response_s_Exert_GI', 'response_s_Fetch_GI',
#        'response_s_Travel_GI', 'response_s_Fall_GI',
#        'response_s_Think_GI', 'response_s_Know_GI',
#        'response_s_Causal_GI', 'response_s_Ought_GI',
#        'response_s_Perceiv_GI', 'response_s_Compare_GI',
#        'response_s_Eval_2_GI', 'response_s_Eval_GI',
#        'response_s_Solve_GI', 'response_s_Abs_2_GI', 'response_s_Abs_GI',
#        'response_s_Quality_GI', 'response_s_Quan_GI',
#        'response_s_Numb_GI', 'response_s_Ord_GI', 'response_s_Card_GI',
#        'response_s_Freq_GI', 'response_s_Dist_GI', 'response_s_Time_2_GI',
#        'response_s_Time_GI', 'response_s_Space_GI', 'response_s_Pos_GI',
#        'response_s_Dim_GI', 'response_s_Rel_GI', 'response_s_Color_GI',
#        'response_s_Self_GI', 'response_s_Our_GI', 'response_s_You_GI',
#        'response_s_Name_GI', 'response_s_Yes_GI', 'response_s_No_GI',
#        'response_s_Negate_GI', 'response_s_Intrj_GI', 'response_s_Iav_GI',
#        'response_s_Dav_GI', 'response_s_Sv_GI', 'response_s_Ipadj_GI',
#        'response_s_Indadj_GI', 'response_s_Powgain_Lasswell',
#        'response_s_Powloss_Lasswell', 'response_s_Powends_Lasswell',
#        'response_s_Powaren_Lasswell', 'response_s_Powcon_Lasswell',
#        'response_s_Powcoop_Lasswell', 'response_s_Powaupt_Lasswell',
#        'response_s_Powpt_Lasswell', 'response_s_Powdoct_Lasswell',
#        'response_s_Powauth_Lasswell', 'response_s_Powoth_Lasswell',
#        'response_s_Powtot_Lasswell', 'response_s_Rcethic_Lasswell',
#        'response_s_Rcrelig_Lasswell', 'response_s_Rcgain_Lasswell',
#        'response_s_Rcloss_Lasswell', 'response_s_Rcends_Lasswell',
#        'response_s_Rctot_Lasswell', 'response_s_Rspgain_Lasswell',
#        'response_s_Rsploss_Lasswell', 'response_s_Rspoth_Lasswell',
#        'response_s_Rsptot_Lasswell', 'response_s_Affgain_Lasswell',
#        'response_s_Affloss_Lasswell', 'response_s_Affpt_Lasswell',
#        'response_s_Affoth_Lasswell', 'response_s_Afftot_Lasswell',
#        'response_s_Wltpt_Lasswell', 'response_s_Wlttran_Lasswell',
#        'response_s_Wltoth_Lasswell', 'response_s_Wlttot_Lasswell',
#        'response_s_Wlbgain_Lasswell', 'response_s_Wlbloss_Lasswell',
#        'response_s_Wlbphys_Lasswell', 'response_s_Wlbpsyc_Lasswell',
#        'response_s_Wlbpt_Lasswell', 'response_s_Wlbtot_Lasswell',
#        'response_s_Enlgain_Lasswell', 'response_s_Enlloss_Lasswell',
#        'response_s_Enlends_Lasswell', 'response_s_Enlpt_Lasswell',
#        'response_s_Enloth_Lasswell', 'response_s_Enltot_Lasswell',
#        'response_s_Sklasth_Lasswell', 'response_s_Sklpt_Lasswell',
#        'response_s_Skloth_Lasswell', 'response_s_Skltot_Lasswell',
#        'response_s_Trngain_Lasswell', 'response_s_Trnloss_Lasswell',
#        'response_s_Tranlw_Lasswell', 'response_s_Meanslw_Lasswell',
#        'response_s_Endslw_Lasswell', 'response_s_Arenalw_Lasswell',
#        'response_s_Ptlw_Lasswell', 'response_s_Nation_Lasswell',
#        'response_s_Anomie_Lasswell', 'response_s_Negaff_Lasswell',
#        'response_s_Posaff_Lasswell', 'response_s_Surelw_Lasswell',
#        'response_s_If_Lasswell', 'response_s_Notlw_Lasswell',
#        'response_s_Timespc_Lasswell', 'response_s_formlw_Lasswell',
#        'response_s_Anger_NRC', 'response_s_Anticipation_NRC',
#        'response_s_Disgust_NRC', 'response_s_Fear_NRC',
#        'response_s_Joy_NRC', 'response_s_Negative_NRC',
#        'response_s_Positive_NRC', 'response_s_Sadness_NRC',
#        'response_s_Surprise_NRC', 'response_s_Trust_NRC',
#        'response_s_negative_words', 'response_s_positive_words',
#        'prompt_e_help', 'prompt_e_office', 'prompt_e_dance',
#        'prompt_e_money', 'prompt_e_wedding', 'prompt_e_domestic_work',
#        'prompt_e_sleep', 'prompt_e_medical_emergency', 'prompt_e_cold',
#        'prompt_e_hate', 'prompt_e_cheerfulness', 'prompt_e_aggression',
#        'prompt_e_occupation', 'prompt_e_envy', 'prompt_e_anticipation',
#        'prompt_e_family', 'prompt_e_vacation', 'prompt_e_crime',
#        'prompt_e_attractive', 'prompt_e_masculine', 'prompt_e_prison',
#        'prompt_e_health', 'prompt_e_pride', 'prompt_e_dispute',
#        'prompt_e_nervousness', 'prompt_e_government', 'prompt_e_weakness',
#        'prompt_e_horror', 'prompt_e_swearing_terms', 'prompt_e_leisure',
#        'prompt_e_suffering', 'prompt_e_royalty', 'prompt_e_wealthy',
#        'prompt_e_tourism', 'prompt_e_furniture', 'prompt_e_school',
#        'prompt_e_magic', 'prompt_e_beach', 'prompt_e_journalism',
#        'prompt_e_morning', 'prompt_e_banking', 'prompt_e_social_media',
#        'prompt_e_exercise', 'prompt_e_night', 'prompt_e_kill',
#        'prompt_e_blue_collar_job', 'prompt_e_art', 'prompt_e_ridicule',
#        'prompt_e_play', 'prompt_e_computer', 'prompt_e_college',
#        'prompt_e_optimism', 'prompt_e_stealing', 'prompt_e_real_estate',
#        'prompt_e_home', 'prompt_e_divine', 'prompt_e_sexual',
#        'prompt_e_fear', 'prompt_e_irritability', 'prompt_e_superhero',
#        'prompt_e_business', 'prompt_e_driving', 'prompt_e_pet',
#        'prompt_e_childish', 'prompt_e_cooking', 'prompt_e_exasperation',
#        'prompt_e_religion', 'prompt_e_hipster', 'prompt_e_internet',
#        'prompt_e_surprise', 'prompt_e_reading', 'prompt_e_worship',
#        'prompt_e_leader', 'prompt_e_independence', 'prompt_e_movement',
#        'prompt_e_body', 'prompt_e_noise', 'prompt_e_eating',
#        'prompt_e_medieval', 'prompt_e_zest', 'prompt_e_confusion',
#        'prompt_e_water', 'prompt_e_sports', 'prompt_e_death',
#        'prompt_e_healing', 'prompt_e_legend', 'prompt_e_heroic',
#        'prompt_e_celebration', 'prompt_e_restaurant', 'prompt_e_violence',
#        'prompt_e_programming', 'prompt_e_dominant_heirarchical',
#        'prompt_e_military', 'prompt_e_neglect', 'prompt_e_swimming',
#        'prompt_e_exotic', 'prompt_e_love', 'prompt_e_hiking',
#        'prompt_e_communication', 'prompt_e_hearing', 'prompt_e_order',
#        'prompt_e_sympathy', 'prompt_e_hygiene', 'prompt_e_weather',
#        'prompt_e_anonymity', 'prompt_e_trust', 'prompt_e_ancient',
#        'prompt_e_deception', 'prompt_e_fabric', 'prompt_e_air_travel',
#        'prompt_e_fight', 'prompt_e_dominant_personality',
#        'prompt_e_music', 'prompt_e_vehicle', 'prompt_e_politeness',
#        'prompt_e_toy', 'prompt_e_farming', 'prompt_e_meeting',
#        'prompt_e_war', 'prompt_e_speaking', 'prompt_e_listen',
#        'prompt_e_urban', 'prompt_e_shopping', 'prompt_e_disgust',
#        'prompt_e_fire', 'prompt_e_tool', 'prompt_e_phone',
#        'prompt_e_gain', 'prompt_e_sound', 'prompt_e_injury',
#        'prompt_e_sailing', 'prompt_e_rage', 'prompt_e_science',
#        'prompt_e_work', 'prompt_e_appearance', 'prompt_e_valuable',
#        'prompt_e_warmth', 'prompt_e_youth', 'prompt_e_sadness',
#        'prompt_e_fun', 'prompt_e_emotional', 'prompt_e_joy',
#        'prompt_e_affection', 'prompt_e_traveling', 'prompt_e_fashion',
#        'prompt_e_ugliness', 'prompt_e_lust', 'prompt_e_shame',
#        'prompt_e_torment', 'prompt_e_economics', 'prompt_e_anger',
#        'prompt_e_politics', 'prompt_e_ship', 'prompt_e_clothing',
#        'prompt_e_car', 'prompt_e_strength', 'prompt_e_technology',
#        'prompt_e_breaking', 'prompt_e_shape_and_size', 'prompt_e_power',
#        'prompt_e_white_collar_job', 'prompt_e_animal', 'prompt_e_party',
#        'prompt_e_terrorism', 'prompt_e_smell', 'prompt_e_disappointment',
#        'prompt_e_poor', 'prompt_e_plant', 'prompt_e_pain',
#        'prompt_e_beauty', 'prompt_e_timidity', 'prompt_e_philosophy',
#        'prompt_e_negotiate', 'prompt_e_negative_emotion',
#        'prompt_e_cleaning', 'prompt_e_messaging', 'prompt_e_competing',
#        'prompt_e_law', 'prompt_e_friends', 'prompt_e_payment',
#        'prompt_e_achievement', 'prompt_e_alcohol', 'prompt_e_liquid',
#        'prompt_e_feminine', 'prompt_e_weapon', 'prompt_e_children',
#        'prompt_e_monster', 'prompt_e_ocean', 'prompt_e_giving',
#        'prompt_e_contentment', 'prompt_e_writing', 'prompt_e_rural',
#        'prompt_e_positive_emotion', 'prompt_e_musical', 'response_e_help',
#        'response_e_office', 'response_e_dance', 'response_e_money',
#        'response_e_wedding', 'response_e_domestic_work',
#        'response_e_sleep', 'response_e_medical_emergency',
#        'response_e_cold', 'response_e_hate', 'response_e_cheerfulness',
#        'response_e_aggression', 'response_e_occupation',
#        'response_e_envy', 'response_e_anticipation', 'response_e_family',
#        'response_e_vacation', 'response_e_crime', 'response_e_attractive',
#        'response_e_masculine', 'response_e_prison', 'response_e_health',
#        'response_e_pride', 'response_e_dispute', 'response_e_nervousness',
#        'response_e_government', 'response_e_weakness',
#        'response_e_horror', 'response_e_swearing_terms',
#        'response_e_leisure', 'response_e_suffering', 'response_e_royalty',
#        'response_e_wealthy', 'response_e_tourism', 'response_e_furniture',
#        'response_e_school', 'response_e_magic', 'response_e_beach',
#        'response_e_journalism', 'response_e_morning',
#        'response_e_banking', 'response_e_social_media',
#        'response_e_exercise', 'response_e_night', 'response_e_kill',
#        'response_e_blue_collar_job', 'response_e_art',
#        'response_e_ridicule', 'response_e_play', 'response_e_computer',
#        'response_e_college', 'response_e_optimism', 'response_e_stealing',
#        'response_e_real_estate', 'response_e_home', 'response_e_divine',
#        'response_e_sexual', 'response_e_fear', 'response_e_irritability',
#        'response_e_superhero', 'response_e_business',
#        'response_e_driving', 'response_e_pet', 'response_e_childish',
#        'response_e_cooking', 'response_e_exasperation',
#        'response_e_religion', 'response_e_hipster', 'response_e_internet',
#        'response_e_surprise', 'response_e_reading', 'response_e_worship',
#        'response_e_leader', 'response_e_independence',
#        'response_e_movement', 'response_e_body', 'response_e_noise',
#        'response_e_eating', 'response_e_medieval', 'response_e_zest',
#        'response_e_confusion', 'response_e_water', 'response_e_sports',
#        'response_e_death', 'response_e_healing', 'response_e_legend',
#        'response_e_heroic', 'response_e_celebration',
#        'response_e_restaurant', 'response_e_violence',
#        'response_e_programming', 'response_e_dominant_heirarchical',
#        'response_e_military', 'response_e_neglect', 'response_e_swimming',
#        'response_e_exotic', 'response_e_love', 'response_e_hiking',
#        'response_e_communication', 'response_e_hearing',
#        'response_e_order', 'response_e_sympathy', 'response_e_hygiene',
#        'response_e_weather', 'response_e_anonymity', 'response_e_trust',
#        'response_e_ancient', 'response_e_deception', 'response_e_fabric',
#        'response_e_air_travel', 'response_e_fight',
#        'response_e_dominant_personality', 'response_e_music',
#        'response_e_vehicle', 'response_e_politeness', 'response_e_toy',
#        'response_e_farming', 'response_e_meeting', 'response_e_war',
#        'response_e_speaking', 'response_e_listen', 'response_e_urban',
#        'response_e_shopping', 'response_e_disgust', 'response_e_fire',
#        'response_e_tool', 'response_e_phone', 'response_e_gain',
#        'response_e_sound', 'response_e_injury', 'response_e_sailing',
#        'response_e_rage', 'response_e_science', 'response_e_work',
#        'response_e_appearance', 'response_e_valuable',
#        'response_e_warmth', 'response_e_youth', 'response_e_sadness',
#        'response_e_fun', 'response_e_emotional', 'response_e_joy',
#        'response_e_affection', 'response_e_traveling',
#        'response_e_fashion', 'response_e_ugliness', 'response_e_lust',
#        'response_e_shame', 'response_e_torment', 'response_e_economics',
#        'response_e_anger', 'response_e_politics', 'response_e_ship',
#        'response_e_clothing', 'response_e_car', 'response_e_strength',
#        'response_e_technology', 'response_e_breaking',
#        'response_e_shape_and_size', 'response_e_power',
#        'response_e_white_collar_job', 'response_e_animal',
#        'response_e_party', 'response_e_terrorism', 'response_e_smell',
#        'response_e_disappointment', 'response_e_poor', 'response_e_plant',
#        'response_e_pain', 'response_e_beauty', 'response_e_timidity',
#        'response_e_philosophy', 'response_e_negotiate',
#        'response_e_negative_emotion', 'response_e_cleaning',
#        'response_e_messaging', 'response_e_competing', 'response_e_law',
#        'response_e_friends', 'response_e_payment',
#        'response_e_achievement', 'response_e_alcohol',
#        'response_e_liquid', 'response_e_feminine', 'response_e_weapon',
#        'response_e_children', 'response_e_monster', 'response_e_ocean',
#        'response_e_giving', 'response_e_contentment',
#        'response_e_writing', 'response_e_rural',
#        'response_e_positive_emotion', 'response_e_musical',
#        'prompt_v_neg', 'prompt_v_neu', 'prompt_v_pos',
#        'prompt_v_compound', 'response_v_neg', 'response_v_neu',
#        'response_v_pos', 'response_v_compound',
#        'prompt_response_similarity'], dtype=object)
